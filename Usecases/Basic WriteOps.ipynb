# %%
df = spark.read.csv("/Volumes/workspace/default/volumewe47/raw/customer.csv", header=True)

df1 = df.write.json("/Volumes/workspace/default/volumewe47_datalake/serialized_data/json_formatteddata", mode="overwrite")

#write to json from csv using one line
#spark.read.csv("/Volumes/workspace/default/volumewe47/raw/customer.csv").write.format("json").save("/Volumes/workspace/default/volumewe47_datalake/serialized_data/json_formatteddata_new")
