-- %%
select * from telecom_bronze.dim_device_bronze

-- %%
select * from telecom_bronze.bronze_dim_tower

-- %%
select * from telecom_silver.dim_towers1_silver

-- %%
    SELECT hash(t.device_type, t.brand, t.model, t.os, t.owner_customer_id, t.status) FROM 
     telecom_gold.dim_device_gold_scd2 t

-- %%
select * from telecom_silver.dim_device_silver

-- %%
select * from telecom_gold.dim_device_gold_scd1 order by device_id, updated_at

-- %%
select * from telecom_gold.dim_device_gold_scd2 order by device_id, updated_at

-- %%
select * from telecom_gold.dim_towers1_gold_scd1

-- %%
select * from telecom_gold.dim_towers1_gold_scd2

-- %%
select * from azdatabricksde0526.telecom_silver.cdr_silver_tbl
--select * from azdatabricksde0526.telecom_bronze.cdr_bronze_tbl

-- %%
%sql
select * from telecom_gold.fact_wide_cdr -- where caller_id=9840800131

--select count(*) from telecom_gold.fact_wide_cdr where region is null

-- %%
select count(*) from telecom_gold.fact_wide_cdr where region is null

-- %%
select count(*) from telecom_gold.fact_wide_cdr where brand is null

-- %%
select * from telecom_gold.fact_realtime_customer_aggr --where caller_id=9840800131;
