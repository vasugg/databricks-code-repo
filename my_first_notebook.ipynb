# %% [markdown]
# ![](https://fplogoimages.withfloats.com/actual/68009c3a43430aff8a30419d.png)

# %% [markdown]
# #Lets learn how to work in notebooks

# %% [markdown]
# ## Lets create markdown designs

# %% [markdown]
# ##Lets learn magic commands

# %% [markdown]
# ###Lets learn %sh magic command

# %%
# %sh ls -l /home/spark-c799a53d-6b9f-4442-ba04-aa

# %% [markdown]
# ###Lets learn %fs magic command
